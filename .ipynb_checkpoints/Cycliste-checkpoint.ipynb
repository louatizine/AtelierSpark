# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window
from pyspark.sql.types import *

# Création de la session Spark
spark = SparkSession.builder \
    .appName("AnalyseCyclistes") \
    .config("spark.sql.adaptive.enabled", "true") \
    .getOrCreate()

# %%
schema = StructType([
    StructField("id_cycliste", IntegerType(), True),
    StructField("timestamp", TimestampType(), True),
    StructField("sur_velo", BooleanType(), True),
    StructField("velo", BooleanType(), True),
    StructField("vitesse", DoubleType(), True),
    StructField("position", StringType(), True),
    StructField("destination_finale", BooleanType(), True)
])

# Chargement des données
df_cyclistes = spark.read \
    .option("delimiter", "\t") \
    .option("header", "false") \
    .schema(schema) \
    .csv("cycliste_1.csv")

# Aperçu des données
df_cyclistes.show(10)
df_cyclistes.printSchema()
# Out:
# +-----------+---------+--------+----+-------+--------+------------------+
# |id_cycliste|timestamp|sur_velo|velo|vitesse|position|destination_finale|
# +-----------+---------+--------+----+-------+--------+------------------+
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# |       NULL|     NULL|    NULL|NULL|   NULL|    NULL|              NULL|
# +-----------+---------+--------+----+-------+--------+------------------+
# only showing top 10 rows
#
# root
#  |-- id_cycliste: integer (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- sur_velo: boolean (nullable = true)
#  |-- velo: boolean (nullable = true)
#  |-- vitesse: double (nullable = true)
#  |-- position: string (nullable = true)
#  |-- destination_finale: boolean (nullable = true)

# %%
sample_data = spark.read.text("Cyclistes_1.csv").limit(10)
sample_data.show(truncate=False)

# Essayons avec différents délimiteurs
df_cyclistes = spark.read \
    .option("delimiter", " ") \
    .option("header", "false") \
    .schema(schema) \
    .csv("Cyclistes_1.csv")

df_cyclistes.show(10, truncate=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sample_data = spark.read.text("Cyclistes_1.csv").limit(10)
#       2 sample_data.show(truncate=False)
#       4 # Essayons avec différents délimiteurs
#
# NameError: name 'spark' is not defined
